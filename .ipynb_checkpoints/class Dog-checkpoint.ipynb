# %%
class Dog:
    def __init__(self, name, gender, breed, age, weight, color):
        self.name = name
        self.gender = gender
        self.breed = breed
       
        # encapsulate
        self.age = age #private attribute
        self.weight = weight
        self.color = color
        
        def setAge(self, newAge):
            if newAge < self.__age:
               print("Error !!")
            else:
                slse.__age = newAge
    
    def showInfo(self):
        print("""
ชื่อ: {}
เพศ: {}
สายพันธุ์: {}
อายุ: {}
น้ำหนัก: {}
สี: {}
""".format(
            self.name,
            self.gender,
            self.breed,
            self.age,
            self.weight,
            self.color
        ))

    def sit(self):
        print("{} is sitting !!".format(self.name))

    def sleep(self):
        print("{} is sleeping !!".format(self.name))

    def eat(self):
        print("{} is eating !!".format(self.name))

# %%
# Instance Variable / object
dog_ker = Dog("เกอร์", "เมีย", "ชิวาวา", 4, 20, "ดำ")
dog_war = Dog("วาร์", "ผู้", "บลูด็อก", 4, 20, "ขาว")

# %%
dog_ker.showInfo()
# Out:
# ชื่อ: เกอร์
# เพศ: เมีย
# สายพันธุ์: ชิวาวา
# อายุ: 100
# น้ำหนัก: 20
# สี: ดำ

# %%
dog_war.showInfo()
# Out:
# ชื่อ: วาร์
# เพศ: ผู้
# สายพันธุ์: บลูด็อก
# อายุ: 99
# น้ำหนัก: 20
# สี: ขาว
